# %%
! git clone https://github.com/hongtienhaolk2001/Graduate_Thesis
# Out:
# Cloning into 'QN-Hackathon-CTA-Matrix'...
# remote: Enumerating objects: 622, done.
# remote: Counting objects: 100% (176/176), done.
# remote: Compressing objects: 100% (118/118), done.
# remote: Total 622 (delta 74), reused 136 (delta 46), pack-reused 446
# Receiving objects: 100% (622/622), 61.28 MiB | 19.68 MiB/s, done.
# Resolving deltas: 100% (290/290), done.

# %%
# %cd Graduate_Thesis/training
# Out:
# /content/QN-Hackathon-CTA-Matrix/training

# %%
! ls
# Out:
# loss.py		   model.py		README.md	  train.py   weights
# merge_datasets.py  preprocess_crawl.py	requirements.txt  utils.py
# metrics.py	   preprocessing.py	split_dataset.py  vncorenlp

# %%
! pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 96 kB 4.5 MB/s
# ...
#      |████████████████████████████████| 101 kB 11.4 MB/s
# ...
#      |████████████████████████████████| 101 kB 13.0 MB/s
# ...
#      |████████████████████████████████| 61 kB 8.0 MB/s
# ...
#      |████████████████████████████████| 133 kB 71.3 MB/s
# ...
#      |████████████████████████████████| 751 kB 62.0 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.9 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 42.1 MB/s
# ...
#      |████████████████████████████████| 4.7 MB 16.7 MB/s
# ...
#      |████████████████████████████████| 139 kB 73.8 MB/s
# ...
#      |████████████████████████████████| 2.6 MB 44.5 MB/s
# ...
#      |████████████████████████████████| 232 kB 59.6 MB/s
# ...
#      |████████████████████████████████| 365 kB 77.5 MB/s
# ...
#      |████████████████████████████████| 115 kB 74.8 MB/s
# ...
#      |████████████████████████████████| 212 kB 70.8 MB/s
# ...

# %%
# !python train.py
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Using custom data configuration default-726438d34e6a0530
# Reusing dataset csv (/root/.cache/huggingface/datasets/csv/default-726438d34e6a0530/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a)
# 100% 2/2 [00:00<00:00, 633.72it/s]
# Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/default-726438d34e6a0530/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a/cache-1a4f167296b2abb5.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/default-726438d34e6a0530/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a/cache-28b5776758b1bcc0.arrow
# 100% 4299/4299 [00:20<00:00, 211.50ex/s]
# 100% 1074/1074 [00:03<00:00, 270.52ex/s]
# 100% 5/5 [00:01<00:00,  3.95ba/s]
# 100% 2/2 [00:00<00:00,  6.92ba/s]
# 100% 4299/4299 [00:00<00:00, 4314.85ex/s]
# ...
